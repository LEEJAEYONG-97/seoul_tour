# %%
pip install webdriver-manager --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting webdriver-manager
#   Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests in c:\users\m\appdata\roaming\python\python311\site-packages (from webdriver-manager) (2.25.1)
# Requirement already satisfied: python-dotenv in c:\anaconda3\lib\site-packages (from webdriver-manager) (0.21.0)
# Requirement already satisfied: packaging in c:\anaconda3\lib\site-packages (from webdriver-manager) (23.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\anaconda3\lib\site-packages (from requests->webdriver-manager) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\m\appdata\roaming\python\python311\site-packages (from requests->webdriver-manager) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\m\appdata\roaming\python\python311\site-packages (from requests->webdriver-manager) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\m\appdata\roaming\python\python311\site-packages (from requests->webdriver-manager) (2024.7.4)
# Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Installing collected packages: webdriver-manager
# Successfully installed webdriver-manager-4.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium.webdriver.common.by import By
from urllib3.util.retry import Retry
from requests.adapters import HTTPAdapter
from openpyxl import Workbook
from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time
import datetime
import requests
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from urllib3.util.retry import Retry
from requests.adapters import HTTPAdapter
from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import re
from selenium.webdriver.common.keys import Keys
import time
import requests

# url
url = 'https://m.place.naver.com/place/11796387/review/visitor?selectedReview=66d7bc3a017082c8b751d896&entry=plt'

# Webdriver headless mode setting
options = webdriver.ChromeOptions()
# options.add_argument('headless')
options.add_argument('window-size=1920x1080')
options.add_argument("disable-gpu")

# BS4 setting for secondary access
session = requests.Session()
headers = {
    "User-Agent": "user value"}

retries = Retry(total=5,
                backoff_factor=0.1,
                status_forcelist=[500, 502, 503, 504])

session.mount('http://', HTTPAdapter(max_retries=retries))

# New xlsx file
now = datetime.datetime.now()
xlsx = Workbook()
list_sheet = xlsx.create_sheet('output')
list_sheet.append(['nickname', 'content', 'date', 'revisit'])

# Start crawling/scraping!
try:
    # driver = webdriver.Chrome(executable_path=ChromeDriverManager().install(), options=options)
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
    res = driver.get(url)
    driver.implicitly_wait(30)

    # Pagedown
    driver.find_element(By.TAG_NAME, 'body').send_keys(Keys.PAGE_DOWN)

    try:
        for i in range(30):  # 최대 30번 반복
            driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[2]/div/a').click()
            time.sleep(0.4)
    except Exception as e:
        print('finish')
    else :
        print('30times_finish')

    time.sleep(25)
    html = driver.page_source
    bs = BeautifulSoup(html, 'lxml')
    reviews = bs.select('li.pui__X35jYm.EjjAW')

    for r in reviews:
        # nickname
        nickname = r.select_one('div.pui__JiVbY3 > span.pui__uslU0d')

        # content
        content = r.select_one('div.pui__vn15t2 > a.pui__xtsQN-')

        # date
        date_elements = r.select('div.pui__QKE5Pr > span.pui__gfuUIT > time')
        date = date_elements[0] if date_elements else 'N/A'

        # revisit
        revisit_span = r.select('div.pui__QKE5Pr > span.pui__gfuUIT')
        revisit = revisit_span[1] if len(revisit_span) > 1 else 'N/A'

        # exception handling
        nickname = nickname.text if nickname else ''
        content = content.text if content else ''
        date = date.text if date else ''
        revisit = revisit.text if revisit else ''
        time.sleep(0.06)

        # append sheet
        print(nickname, '/', content, '/', date, '/', revisit)
        list_sheet.append([nickname, content, date, revisit])
        time.sleep(0.06)
    # Save the file
    file_name = 'naver_review_' + now.strftime('%Y-%m-%d_%H-%M-%S') + '.xlsx'
    xlsx.save(file_name)

except Exception as e:
    print(e)
    # Save the file(temp)
    file_name = 'naver_review_' + now.strftime('%Y-%m-%d_%H-%M-%S') + '.xlsx'
    xlsx.save(file_name)
# Out:
# finish
# 금쪽같은태복이 / 서울어린이 대공원 처음 가봤는데너무 너무 좋았어요아이, 어른 누구나 좋겠더라구요놀이기구 아니더라도 분수도 나오고 큰 놀이터도 있고 동물원(오후5시까지) 공원이 잘되어있어 산책하기도 좋겠더라구요~놀이공원은 모두 표를 끊어야되는거 아니고기구 탈 사람만 끊어도 되니 좋았어요초2 남아인데 5종 끊어서 알차게 잘 탔어요놀이공원이 크지않아요 그래도 즐기기 충분해요 !주말에는 오후7시반까지 하니 좋고당일 인터넷 예약이 마감이라 전화했더니현장 발권이 되더라구요 ^^ / 8.31.토 / 1번째 방문
# 이주 / 한달도 안돼서 재방문 했어요!!! 역시나 평일이라 그런지 사람이 정말 없어서 쾌적하게 이용할 수 있었습니다~ 이번에도 대기시간은 총 3분정도 된 것 같아요. 사람이 없다보니까 A놀이기구 운행 후 B놀이기구 진행 이런식으로 운행으 되거든요~~ 그래도 다른 놀이공원에 비하면 개꿀이라는 부분,, 저번에 못봤던 물새장도 갔는데 펭귄이 여기 있었더라고요.맹수마을은 울타리 공사중이어서 코끼리나 호랑이 등을 못봤는데 약간 아쉬웠어요. 날이 너무 더워져서 그런지 동물들이 대부분 그늘로 피해있거나 힘이 없어보이긴 했어요😭 그래도 도심 속에서 놀이기구 즐기고 싶으면 또 어린이대공원으로 올거예요☺️ 최애 대공원으로 임명합니다💐🍀 / 6.21.금 / 2번째 방문
# 행복한의사 / 최고의 나들이 장소동물원입장료 무료유모차대여 웨건 8000원 쌍둥이유모차 5000원 일반유모차 3000원놀이공원 입장료없이 놀이기구 탈 사람만횟수단위  1,3,5회권  또는 자유이용권 끊어서타면 됨(타놀이공원은 입장하려면 자유이용권 끊어야하는데 놀이기구 안탈사람은 안 끊어도  되니  너무 좋았음)110-130cm사이는 보호자동반이 많아서 보호자도 표끊어야함130cm이상은 탈것 센게 좀 있음아이들 놀이터도 잘 만들어져 있고 놀이공원은 놀이기구 사이사이  매점이나 음료수,아이스크림 파는곳이 있는것도 좋았음가족단위로 나들이가기 너무 좋은 곳! 강추 세게 날립니다.아이들이 진짜 좋아합니다. / 6.9.일 / 1번째 방문
# ttottoo / 신나게 놀이기구도 타고동물원과 놀이터, 음악분수까지!집근처에 어린이대공원이 있어서 정말정말 행복합니다 :) / 5.12.일 / 2번째 방문
# 하늘채랑 / 사람이 많이 줄었어요그래서 대기없이 탈 수 있는 동시에탈 것도 별로 많지않아요어린이대공원이 쇠퇴하는게 느껴져서 슬펐어요 / 6.11.화 / 1번째 방문
# doori0523 / 매년 오는곳.올때마다 청솔모도 보고평일에 가면 놀이기구도 많이 타고 좋았어요. / 5.28.화 / 7번째 방문
# YJY025 / 운동 끝나고 음료수 사기 편해요 / 7.1.월 / 1번째 방문
# 성격파탄 이지민 / 주차가 조금 힘들었어요아이들은 동물도 보고 놀이기구도 타고 엄청 좋아했어요 / 5.24.금 / 1번째 방문
# 솔직한리뷰어12 / 네이버 예약했다고 매표소에 이름이랑 전화번호 뒷자리 알려드렸는데 찾을 수 없다고;;그렇게 5분 정도는 매표소 앞에서 기다린 것 같아요.결국 예매번호 알려드리고 티켓 받았는데 늦어서 죄송하다는 한마디도 못듣고 티켓 받았어요.연세가 있으셔서 시스템을 잘 모르시는건지…교육 좀 받으셨으면 합니다. / 5.17.금 / 2번째 방문
# 행복 한아람 / 번지드롭? 후룸라이드 같은 놀이기구가 점검이라 아쉬웠어요ㅜㅜ훼밀리코스타 바이킹은 운영해서 그나마 다행~ 그래도 없어지지않고 잘 운영 되었음 좋겠습니다^^ / 6.23.일 / 4번째 방문
# 기분좋은원 / 줄이 짧아서 기다림에 덜 지치고, 나름 롤러코스터나 후룸라이드 바이킹이 있으나 110-120사이 아이는 못 타는게 있는데, 타는건 또 시시해 할 수 있겠어요. 한달새 두번 가서 나중에 나중에 한두개만 타러 갈 듯. 시설에 비해 자유이용권 비싸요. / 4.27.토 / 1번째 방문
# 하율사랑맘 / 즐겁게 돌아다니는 딸보니 좋았어요..기구도 여러개탔다며 집에오는길에 주저리 주저리 쉴세없이 재잘재잘~~집에와서 많이 돌아다녀서 발바닥 아프다면 일찍 잠이 들었네요.^^* / 6.7.금 / 1번째 방문
# bot**** / 아이들이 너무 재미있게 놀이기구 탔어요 대기시간도 많이 기다리지않고 바로바로 탈수있어서 더 좋았어요^^ 후룸라이드만 못타서 그게 제일 아쉬웠지만 다음을 기약하면서~~ 동물원도 즐겁게 구경하고 왔어요 / 4.14.일 / 1번째 방문
# shh**** / 네이버로 예약하면 놀이기구 big5 할인 받을수있어 좋습니다~재미있는 기구들도 많고 아이가 정말 좋아해요^^ / 5.1.수 / 2번째 방문
# idb**** / 너무 재미있게 놀다왔어요 가성비 짱❤️ / 7.28.일 / 1번째 방문
# 나래7038 / 토요일 점심 지나서 방문했고 3회권 끊었는데 후룸라이드 빼고는 별로 안 기다렸어요! 가볍게 놀기에 좋네요ㅎㅎ / 5.25.토 / 1번째 방문
# kid**** / 맛있어요 고기도 부드럽고 아이들도 잘먹어요 / 5.19.일 / 1번째 방문
